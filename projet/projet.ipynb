# %%
import re
import csv
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd
import numpy as np
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
import nltk
import json
from tqdm import tqdm
import ir_datasets
import pyterrier as pt
from langdetect import detect, DetectorFactory
import random
import math
from collections import Counter
if not pt.started():
	pt.init(boot_packages=["com.github.terrierteam:terrier-prf:-SNAPSHOT"])
# Out:
# C:\Users\yacin\AppData\Local\Temp\ipykernel_5916\3225328329.py:17: DeprecationWarning: Call to deprecated function (or staticmethod) started. (use pt.java.started() instead) -- Deprecated since version 0.11.0.
#   if not pt.started():
# Java started and loaded: pyterrier.java, pyterrier.terrier.java [version=5.11 (build: craig.macdonald 2025-01-13 21:29), helper_version=0.0.8]
# C:\Users\yacin\AppData\Local\Temp\ipykernel_5916\3225328329.py:18: DeprecationWarning: Call to deprecated method pt.init(). Deprecated since version 0.11.0.
# The following code will have the same effect:
# pt.java.add_package('com.github.terrierteam', 'terrier-prf', '-SNAPSHOT')
# pt.java.init() # optional, forces java initialisation
#   pt.init(boot_packages=["com.github.terrierteam:terrier-prf:-SNAPSHOT"])

# %% [markdown]
# # A- Préparation des données et leur indexation

# %% [markdown]
# ## A-1: making my dataset smaller so the indexation doesn't take days to run

# %%
dataset = ir_datasets.load("istella22/test")
qrels = set(qrel.doc_id for qrel in dataset.qrels_iter())
print(f"Documents pertinents (qrels) : {len(qrels)}")
random.seed(42)
kept_docnos = set()

def iter_docs_filtered(alpha=0.05):
    total = 0
    kept = 0
    for doc in dataset.docs_iter():
        total += 1
        if doc.lang == "en":
            title = doc.title or ""
            text = doc.text or ""
            full_text = f"{title}\n\n{text}"

            if doc.doc_id in qrels:
                kept += 1
                kept_docnos.add(doc.doc_id)
                yield {"docno": doc.doc_id, "text": full_text}
            else:
                if random.random() <= alpha:
                    kept += 1
                    kept_docnos.add(doc.doc_id)
                    yield {"docno": doc.doc_id, "text": full_text}

        if total % 10000 == 0:
            print(f"{total*100/8400000} % des documents traités | {kept} documents retenus de {total} documents traités")

    print(f"Total documents traités : {total} | Documents indexés : {kept}")
# Out:
# Documents pertinents (qrels) : 10436

# %%
indexer = pt.IterDictIndexer("./index", meta={'docno': 20, 'text': 4096}, fields=True)

# %%
# ça m'a pris 43min pour indexer 129k docs sur 8.4M
#indexref = indexer.index(iter_docs_filtered())

indexref = indexer.index(iter_docs_filtered(alpha=0.05))
print(f"Indexation terminée : {indexref}")
# Out:
# 0.11904761904761904 % des documents traités | 84 documents retenus de 10000 documents traités
# 19:12:44.493 [main] WARN org.terrier.structures.indexing.Indexer -- Adding an empty document to the index (1990010000087773) - further warnings are suppressed
# 0.23809523809523808 % des documents traités | 189 documents retenus de 20000 documents traités
# 0.35714285714285715 % des documents traités | 304 documents retenus de 30000 documents traités
# 0.47619047619047616 % des documents traités | 416 documents retenus de 40000 documents traités
# 0.5952380952380952 % des documents traités | 531 documents retenus de 50000 documents traités
# 0.7142857142857143 % des documents traités | 642 documents retenus de 60000 documents traités
# 0.8333333333333334 % des documents traités | 760 documents retenus de 70000 documents traités
# 0.9523809523809523 % des documents traités | 876 documents retenus de 80000 documents traités
# 1.0714285714285714 % des documents traités | 1006 documents retenus de 90000 documents traités
# 1.1904761904761905 % des documents traités | 1142 documents retenus de 100000 documents traités
# 1.3095238095238095 % des documents traités | 1259 documents retenus de 110000 documents traités
# 1.4285714285714286 % des documents traités | 1405 documents retenus de 120000 documents traités
# 1.5476190476190477 % des documents traités | 1527 documents retenus de 130000 documents traités
# 1.6666666666666667 % des documents traités | 1637 documents retenus de 140000 documents traités
# 1.7857142857142858 % des documents traités | 1748 documents retenus de 150000 documents traités
# 1.9047619047619047 % des documents traités | 1860 documents retenus de 160000 documents traités
# 2.0238095238095237 % des documents traités | 1965 documents retenus de 170000 documents traités
# 2.142857142857143 % des documents traités | 2110 documents retenus de 180000 documents traités
# 2.261904761904762 % des documents traités | 2245 documents retenus de 190000 documents traités
# 2.380952380952381 % des documents traités | 2360 documents retenus de 200000 documents traités
# 2.5 % des documents traités | 2486 documents retenus de 210000 documents traités
# 2.619047619047619 % des documents traités | 2602 documents retenus de 220000 documents traités
# 2.738095238095238 % des documents traités | 2713 documents retenus de 230000 documents traités
# 2.857142857142857 % des documents traités | 2832 documents retenus de 240000 documents traités
# 2.9761904761904763 % des documents traités | 2953 documents retenus de 250000 documents traités
# 3.0952380952380953 % des documents traités | 3060 documents retenus de 260000 documents traités
# 3.2142857142857144 % des documents traités | 3187 documents retenus de 270000 documents traités
# 3.3333333333333335 % des documents traités | 3306 documents retenus de 280000 documents traités
# 3.4523809523809526 % des documents traités | 3431 documents retenus de 290000 documents traités
# 3.5714285714285716 % des documents traités | 3556 documents retenus de 300000 documents traités
# 3.6904761904761907 % des documents traités | 3678 documents retenus de 310000 documents traités
# 3.8095238095238093 % des documents traités | 3796 documents retenus de 320000 documents traités
# 3.9285714285714284 % des documents traités | 3904 documents retenus de 330000 documents traités
# 4.0476190476190474 % des documents traités | 4038 documents retenus de 340000 documents traités
# 4.166666666666667 % des documents traités | 4143 documents retenus de 350000 documents traités
# 4.285714285714286 % des documents traités | 4259 documents retenus de 360000 documents traités
# 4.404761904761905 % des documents traités | 4375 documents retenus de 370000 documents traités
# 4.523809523809524 % des documents traités | 4495 documents retenus de 380000 documents traités
# 4.642857142857143 % des documents traités | 4600 documents retenus de 390000 documents traités
# 4.761904761904762 % des documents traités | 4725 documents retenus de 400000 documents traités
# 4.880952380952381 % des documents traités | 4845 documents retenus de 410000 documents traités
# 5.0 % des documents traités | 4968 documents retenus de 420000 documents traités
# 5.119047619047619 % des documents traités | 5100 documents retenus de 430000 documents traités
# 5.238095238095238 % des documents traités | 5210 documents retenus de 440000 documents traités
# 5.357142857142857 % des documents traités | 5319 documents retenus de 450000 documents traités
# 5.476190476190476 % des documents traités | 5422 documents retenus de 460000 documents traités
# 5.595238095238095 % des documents traités | 5550 documents retenus de 470000 documents traités
# 5.714285714285714 % des documents traités | 5655 documents retenus de 480000 documents traités
# 5.833333333333333 % des documents traités | 5778 documents retenus de 490000 documents traités
# 5.9523809523809526 % des documents traités | 5902 documents retenus de 500000 documents traités
# 6.071428571428571 % des documents traités | 6013 documents retenus de 510000 documents traités
# 6.190476190476191 % des documents traités | 6114 documents retenus de 520000 documents traités
# 6.309523809523809 % des documents traités | 6235 documents retenus de 530000 documents traités
# 6.428571428571429 % des documents traités | 6346 documents retenus de 540000 documents traités
# 6.5476190476190474 % des documents traités | 6460 documents retenus de 550000 documents traités
# 6.666666666666667 % des documents traités | 6614 documents retenus de 560000 documents traités
# 6.785714285714286 % des documents traités | 6731 documents retenus de 570000 documents traités
# 6.904761904761905 % des documents traités | 6841 documents retenus de 580000 documents traités
# 7.023809523809524 % des documents traités | 6968 documents retenus de 590000 documents traités
# 7.142857142857143 % des documents traités | 7081 documents retenus de 600000 documents traités
# 7.261904761904762 % des documents traités | 7196 documents retenus de 610000 documents traités
# 7.380952380952381 % des documents traités | 7320 documents retenus de 620000 documents traités
# 7.5 % des documents traités | 7456 documents retenus de 630000 documents traités
# 7.619047619047619 % des documents traités | 7583 documents retenus de 640000 documents traités
# 7.738095238095238 % des documents traités | 7707 documents retenus de 650000 documents traités
# 7.857142857142857 % des documents traités | 7806 documents retenus de 660000 documents traités
# 7.976190476190476 % des documents traités | 7914 documents retenus de 670000 documents traités
# 8.095238095238095 % des documents traités | 8036 documents retenus de 680000 documents traités
# 8.214285714285714 % des documents traités | 8168 documents retenus de 690000 documents traités
# 8.333333333333334 % des documents traités | 8301 documents retenus de 700000 documents traités
# 8.452380952380953 % des documents traités | 8421 documents retenus de 710000 documents traités
# 8.571428571428571 % des documents traités | 8554 documents retenus de 720000 documents traités
# 8.69047619047619 % des documents traités | 8666 documents retenus de 730000 documents traités
# 8.80952380952381 % des documents traités | 8778 documents retenus de 740000 documents traités
# 8.928571428571429 % des documents traités | 8885 documents retenus de 750000 documents traités
# 9.047619047619047 % des documents traités | 9001 documents retenus de 760000 documents traités
# 9.166666666666666 % des documents traités | 9163 documents retenus de 770000 documents traités
# 9.285714285714286 % des documents traités | 9284 documents retenus de 780000 documents traités
# 9.404761904761905 % des documents traités | 9387 documents retenus de 790000 documents traités
# 9.523809523809524 % des documents traités | 9513 documents retenus de 800000 documents traités
# 9.642857142857142 % des documents traités | 9644 documents retenus de 810000 documents traités
# 9.761904761904763 % des documents traités | 9757 documents retenus de 820000 documents traités
# 9.880952380952381 % des documents traités | 9884 documents retenus de 830000 documents traités
# 10.0 % des documents traités | 10002 documents retenus de 840000 documents traités
# 10.119047619047619 % des documents traités | 10122 documents retenus de 850000 documents traités
# 10.238095238095237 % des documents traités | 10235 documents retenus de 860000 documents traités
# 10.357142857142858 % des documents traités | 10340 documents retenus de 870000 documents traités
# 10.476190476190476 % des documents traités | 10447 documents retenus de 880000 documents traités
# 10.595238095238095 % des documents traités | 10562 documents retenus de 890000 documents traités
# 10.714285714285714 % des documents traités | 10692 documents retenus de 900000 documents traités
# 10.833333333333334 % des documents traités | 10790 documents retenus de 910000 documents traités
# 10.952380952380953 % des documents traités | 10903 documents retenus de 920000 documents traités
# 11.071428571428571 % des documents traités | 11014 documents retenus de 930000 documents traités
# 11.19047619047619 % des documents traités | 11156 documents retenus de 940000 documents traités
# 11.30952380952381 % des documents traités | 11260 documents retenus de 950000 documents traités
# 11.428571428571429 % des documents traités | 11364 documents retenus de 960000 documents traités
# 11.547619047619047 % des documents traités | 11487 documents retenus de 970000 documents traités
# 11.666666666666666 % des documents traités | 11626 documents retenus de 980000 documents traités
# 11.785714285714286 % des documents traités | 11779 documents retenus de 990000 documents traités
# 11.904761904761905 % des documents traités | 11903 documents retenus de 1000000 documents traités
# 12.023809523809524 % des documents traités | 12003 documents retenus de 1010000 documents traités
# 12.142857142857142 % des documents traités | 12130 documents retenus de 1020000 documents traités
# 12.261904761904763 % des documents traités | 12241 documents retenus de 1030000 documents traités
# 12.380952380952381 % des documents traités | 12352 documents retenus de 1040000 documents traités
# 12.5 % des documents traités | 12485 documents retenus de 1050000 documents traités
# 12.619047619047619 % des documents traités | 12580 documents retenus de 1060000 documents traités
# 12.738095238095237 % des documents traités | 12721 documents retenus de 1070000 documents traités
# 12.857142857142858 % des documents traités | 12835 documents retenus de 1080000 documents traités
# 12.976190476190476 % des documents traités | 12917 documents retenus de 1090000 documents traités
# 13.095238095238095 % des documents traités | 13012 documents retenus de 1100000 documents traités
# 13.214285714285714 % des documents traités | 13128 documents retenus de 1110000 documents traités
# 13.333333333333334 % des documents traités | 13240 documents retenus de 1120000 documents traités
# 13.452380952380953 % des documents traités | 13348 documents retenus de 1130000 documents traités
# 13.571428571428571 % des documents traités | 13473 documents retenus de 1140000 documents traités
# 13.69047619047619 % des documents traités | 13592 documents retenus de 1150000 documents traités
# 13.80952380952381 % des documents traités | 13713 documents retenus de 1160000 documents traités
# 13.928571428571429 % des documents traités | 13832 documents retenus de 1170000 documents traités
# 14.047619047619047 % des documents traités | 13955 documents retenus de 1180000 documents traités
# 14.166666666666666 % des documents traités | 14089 documents retenus de 1190000 documents traités
# 14.285714285714286 % des documents traités | 14252 documents retenus de 1200000 documents traités
# 14.404761904761905 % des documents traités | 14352 documents retenus de 1210000 documents traités
# 14.523809523809524 % des documents traités | 14467 documents retenus de 1220000 documents traités
# 14.642857142857142 % des documents traités | 14578 documents retenus de 1230000 documents traités
# 14.761904761904763 % des documents traités | 14682 documents retenus de 1240000 documents traités
# 14.880952380952381 % des documents traités | 14800 documents retenus de 1250000 documents traités
# 15.0 % des documents traités | 14924 documents retenus de 1260000 documents traités
# 15.119047619047619 % des documents traités | 15039 documents retenus de 1270000 documents traités
# 15.238095238095237 % des documents traités | 15195 documents retenus de 1280000 documents traités
# 15.357142857142858 % des documents traités | 15301 documents retenus de 1290000 documents traités
# 15.476190476190476 % des documents traités | 15414 documents retenus de 1300000 documents traités
# 15.595238095238095 % des documents traités | 15529 documents retenus de 1310000 documents traités
# 15.714285714285714 % des documents traités | 15644 documents retenus de 1320000 documents traités
# 15.833333333333334 % des documents traités | 15734 documents retenus de 1330000 documents traités
# 15.952380952380953 % des documents traités | 15857 documents retenus de 1340000 documents traités
# 16.071428571428573 % des documents traités | 15987 documents retenus de 1350000 documents traités
# 16.19047619047619 % des documents traités | 16118 documents retenus de 1360000 documents traités
# 16.30952380952381 % des documents traités | 16235 documents retenus de 1370000 documents traités
# 16.428571428571427 % des documents traités | 16354 documents retenus de 1380000 documents traités
# 16.547619047619047 % des documents traités | 16466 documents retenus de 1390000 documents traités
# 16.666666666666668 % des documents traités | 16608 documents retenus de 1400000 documents traités
# 16.785714285714285 % des documents traités | 16753 documents retenus de 1410000 documents traités
# 16.904761904761905 % des documents traités | 16880 documents retenus de 1420000 documents traités
# 17.023809523809526 % des documents traités | 16975 documents retenus de 1430000 documents traités
# 17.142857142857142 % des documents traités | 17087 documents retenus de 1440000 documents traités
# 17.261904761904763 % des documents traités | 17219 documents retenus de 1450000 documents traités
# 17.38095238095238 % des documents traités | 17355 documents retenus de 1460000 documents traités
# 17.5 % des documents traités | 17469 documents retenus de 1470000 documents traités
# 17.61904761904762 % des documents traités | 17598 documents retenus de 1480000 documents traités
# 17.738095238095237 % des documents traités | 17736 documents retenus de 1490000 documents traités
# 17.857142857142858 % des documents traités | 17850 documents retenus de 1500000 documents traités
# 17.976190476190474 % des documents traités | 17958 documents retenus de 1510000 documents traités
# 18.095238095238095 % des documents traités | 18050 documents retenus de 1520000 documents traités
# 18.214285714285715 % des documents traités | 18173 documents retenus de 1530000 documents traités
# 18.333333333333332 % des documents traités | 18286 documents retenus de 1540000 documents traités
# 18.452380952380953 % des documents traités | 18389 documents retenus de 1550000 documents traités
# 18.571428571428573 % des documents traités | 18487 documents retenus de 1560000 documents traités
# 18.69047619047619 % des documents traités | 18614 documents retenus de 1570000 documents traités
# 18.80952380952381 % des documents traités | 18716 documents retenus de 1580000 documents traités
# 18.928571428571427 % des documents traités | 18828 documents retenus de 1590000 documents traités
# 19.047619047619047 % des documents traités | 18942 documents retenus de 1600000 documents traités
# 19.166666666666668 % des documents traités | 19104 documents retenus de 1610000 documents traités
# 19.285714285714285 % des documents traités | 19219 documents retenus de 1620000 documents traités
# 19.404761904761905 % des documents traités | 19347 documents retenus de 1630000 documents traités
# 19.523809523809526 % des documents traités | 19471 documents retenus de 1640000 documents traités
# 19.642857142857142 % des documents traités | 19575 documents retenus de 1650000 documents traités
# 19.761904761904763 % des documents traités | 19698 documents retenus de 1660000 documents traités
# 19.88095238095238 % des documents traités | 19812 documents retenus de 1670000 documents traités
# 20.0 % des documents traités | 19917 documents retenus de 1680000 documents traités
# 20.11904761904762 % des documents traités | 20039 documents retenus de 1690000 documents traités
# 20.238095238095237 % des documents traités | 20172 documents retenus de 1700000 documents traités
# 20.357142857142858 % des documents traités | 20290 documents retenus de 1710000 documents traités
# 20.476190476190474 % des documents traités | 20376 documents retenus de 1720000 documents traités
# 20.595238095238095 % des documents traités | 20497 documents retenus de 1730000 documents traités
# 20.714285714285715 % des documents traités | 20594 documents retenus de 1740000 documents traités
# 20.833333333333332 % des documents traités | 20711 documents retenus de 1750000 documents traités
# 20.952380952380953 % des documents traités | 20838 documents retenus de 1760000 documents traités
# 21.071428571428573 % des documents traités | 20946 documents retenus de 1770000 documents traités
# 21.19047619047619 % des documents traités | 21068 documents retenus de 1780000 documents traités
# 21.30952380952381 % des documents traités | 21190 documents retenus de 1790000 documents traités
# 21.428571428571427 % des documents traités | 21317 documents retenus de 1800000 documents traités
# 21.547619047619047 % des documents traités | 21415 documents retenus de 1810000 documents traités
# 21.666666666666668 % des documents traités | 21574 documents retenus de 1820000 documents traités
# 21.785714285714285 % des documents traités | 21671 documents retenus de 1830000 documents traités
# 21.904761904761905 % des documents traités | 21777 documents retenus de 1840000 documents traités
# 22.023809523809526 % des documents traités | 21885 documents retenus de 1850000 documents traités
# 22.142857142857142 % des documents traités | 22016 documents retenus de 1860000 documents traités
# 22.261904761904763 % des documents traités | 22158 documents retenus de 1870000 documents traités
# 22.38095238095238 % des documents traités | 22261 documents retenus de 1880000 documents traités
# 22.5 % des documents traités | 22368 documents retenus de 1890000 documents traités
# 22.61904761904762 % des documents traités | 22519 documents retenus de 1900000 documents traités
# 22.738095238095237 % des documents traités | 22621 documents retenus de 1910000 documents traités
# 22.857142857142858 % des documents traités | 22739 documents retenus de 1920000 documents traités
# 22.976190476190474 % des documents traités | 22849 documents retenus de 1930000 documents traités
# 23.095238095238095 % des documents traités | 22962 documents retenus de 1940000 documents traités
# 23.214285714285715 % des documents traités | 23088 documents retenus de 1950000 documents traités
# 23.333333333333332 % des documents traités | 23188 documents retenus de 1960000 documents traités
# 23.452380952380953 % des documents traités | 23294 documents retenus de 1970000 documents traités
# 23.571428571428573 % des documents traités | 23405 documents retenus de 1980000 documents traités
# 23.69047619047619 % des documents traités | 23534 documents retenus de 1990000 documents traités
# 23.80952380952381 % des documents traités | 23653 documents retenus de 2000000 documents traités
# 23.928571428571427 % des documents traités | 23752 documents retenus de 2010000 documents traités
# 24.047619047619047 % des documents traités | 23913 documents retenus de 2020000 documents traités
# 24.166666666666668 % des documents traités | 24043 documents retenus de 2030000 documents traités
# 24.285714285714285 % des documents traités | 24167 documents retenus de 2040000 documents traités
# 24.404761904761905 % des documents traités | 24292 documents retenus de 2050000 documents traités
# 24.523809523809526 % des documents traités | 24403 documents retenus de 2060000 documents traités
# 24.642857142857142 % des documents traités | 24507 documents retenus de 2070000 documents traités
# 24.761904761904763 % des documents traités | 24637 documents retenus de 2080000 documents traités
# 24.88095238095238 % des documents traités | 24760 documents retenus de 2090000 documents traités
# 25.0 % des documents traités | 24890 documents retenus de 2100000 documents traités
# 25.11904761904762 % des documents traités | 25015 documents retenus de 2110000 documents traités
# 25.238095238095237 % des documents traités | 25125 documents retenus de 2120000 documents traités
# 25.357142857142858 % des documents traités | 25214 documents retenus de 2130000 documents traités
# 25.476190476190474 % des documents traités | 25342 documents retenus de 2140000 documents traités
# 25.595238095238095 % des documents traités | 25443 documents retenus de 2150000 documents traités
# 25.714285714285715 % des documents traités | 25547 documents retenus de 2160000 documents traités
# 25.833333333333332 % des documents traités | 25651 documents retenus de 2170000 documents traités
# 25.952380952380953 % des documents traités | 25789 documents retenus de 2180000 documents traités
# 26.071428571428573 % des documents traités | 25910 documents retenus de 2190000 documents traités
# 26.19047619047619 % des documents traités | 26020 documents retenus de 2200000 documents traités
# 26.30952380952381 % des documents traités | 26128 documents retenus de 2210000 documents traités
# 26.428571428571427 % des documents traités | 26229 documents retenus de 2220000 documents traités
# 26.547619047619047 % des documents traités | 26389 documents retenus de 2230000 documents traités
# 26.666666666666668 % des documents traités | 26495 documents retenus de 2240000 documents traités
# 26.785714285714285 % des documents traités | 26613 documents retenus de 2250000 documents traités
# 26.904761904761905 % des documents traités | 26742 documents retenus de 2260000 documents traités
# 27.023809523809526 % des documents traités | 26852 documents retenus de 2270000 documents traités
# 27.142857142857142 % des documents traités | 26972 documents retenus de 2280000 documents traités
# 27.261904761904763 % des documents traités | 27094 documents retenus de 2290000 documents traités
# 27.38095238095238 % des documents traités | 27207 documents retenus de 2300000 documents traités
# 27.5 % des documents traités | 27331 documents retenus de 2310000 documents traités
# 27.61904761904762 % des documents traités | 27443 documents retenus de 2320000 documents traités
# 27.738095238095237 % des documents traités | 27533 documents retenus de 2330000 documents traités
# 27.857142857142858 % des documents traités | 27642 documents retenus de 2340000 documents traités
# 27.976190476190474 % des documents traités | 27740 documents retenus de 2350000 documents traités
# 28.095238095238095 % des documents traités | 27865 documents retenus de 2360000 documents traités
# 28.214285714285715 % des documents traités | 27974 documents retenus de 2370000 documents traités
# 28.333333333333332 % des documents traités | 28072 documents retenus de 2380000 documents traités
# 28.452380952380953 % des documents traités | 28187 documents retenus de 2390000 documents traités
# 28.571428571428573 % des documents traités | 28302 documents retenus de 2400000 documents traités
# 28.69047619047619 % des documents traités | 28411 documents retenus de 2410000 documents traités
# 28.80952380952381 % des documents traités | 28526 documents retenus de 2420000 documents traités
# 28.928571428571427 % des documents traités | 28685 documents retenus de 2430000 documents traités
# 29.047619047619047 % des documents traités | 28807 documents retenus de 2440000 documents traités
# 29.166666666666668 % des documents traités | 28929 documents retenus de 2450000 documents traités
# 29.285714285714285 % des documents traités | 29037 documents retenus de 2460000 documents traités
# 29.404761904761905 % des documents traités | 29160 documents retenus de 2470000 documents traités
# 29.523809523809526 % des documents traités | 29263 documents retenus de 2480000 documents traités
# 29.642857142857142 % des documents traités | 29394 documents retenus de 2490000 documents traités
# 29.761904761904763 % des documents traités | 29520 documents retenus de 2500000 documents traités
# 29.88095238095238 % des documents traités | 29632 documents retenus de 2510000 documents traités
# 30.0 % des documents traités | 29752 documents retenus de 2520000 documents traités
# 30.11904761904762 % des documents traités | 29843 documents retenus de 2530000 documents traités
# 30.238095238095237 % des documents traités | 29933 documents retenus de 2540000 documents traités
# 30.357142857142858 % des documents traités | 30045 documents retenus de 2550000 documents traités
# 30.476190476190474 % des documents traités | 30170 documents retenus de 2560000 documents traités
# 30.595238095238095 % des documents traités | 30299 documents retenus de 2570000 documents traités
# 30.714285714285715 % des documents traités | 30420 documents retenus de 2580000 documents traités
# 30.833333333333332 % des documents traités | 30547 documents retenus de 2590000 documents traités
# 30.952380952380953 % des documents traités | 30667 documents retenus de 2600000 documents traités
# 31.071428571428573 % des documents traités | 30781 documents retenus de 2610000 documents traités
# 31.19047619047619 % des documents traités | 30887 documents retenus de 2620000 documents traités
# 31.30952380952381 % des documents traités | 31025 documents retenus de 2630000 documents traités
# 31.428571428571427 % des documents traités | 31185 documents retenus de 2640000 documents traités
# 31.547619047619047 % des documents traités | 31300 documents retenus de 2650000 documents traités
# 31.666666666666668 % des documents traités | 31402 documents retenus de 2660000 documents traités
# 31.785714285714285 % des documents traités | 31514 documents retenus de 2670000 documents traités
# 31.904761904761905 % des documents traités | 31623 documents retenus de 2680000 documents traités
# 32.023809523809526 % des documents traités | 31733 documents retenus de 2690000 documents traités
# 32.142857142857146 % des documents traités | 31878 documents retenus de 2700000 documents traités
# 32.26190476190476 % des documents traités | 32008 documents retenus de 2710000 documents traités
# 32.38095238095238 % des documents traités | 32137 documents retenus de 2720000 documents traités
# 32.5 % des documents traités | 32266 documents retenus de 2730000 documents traités
# 32.61904761904762 % des documents traités | 32350 documents retenus de 2740000 documents traités
# 32.73809523809524 % des documents traités | 32471 documents retenus de 2750000 documents traités
# 32.857142857142854 % des documents traités | 32589 documents retenus de 2760000 documents traités
# 32.976190476190474 % des documents traités | 32724 documents retenus de 2770000 documents traités
# 33.095238095238095 % des documents traités | 32834 documents retenus de 2780000 documents traités
# 33.214285714285715 % des documents traités | 32949 documents retenus de 2790000 documents traités
# 33.333333333333336 % des documents traités | 33058 documents retenus de 2800000 documents traités
# 33.45238095238095 % des documents traités | 33190 documents retenus de 2810000 documents traités
# 33.57142857142857 % des documents traités | 33306 documents retenus de 2820000 documents traités
# 33.69047619047619 % des documents traités | 33419 documents retenus de 2830000 documents traités
# 33.80952380952381 % des documents traités | 33589 documents retenus de 2840000 documents traités
# 33.92857142857143 % des documents traités | 33715 documents retenus de 2850000 documents traités
# 34.04761904761905 % des documents traités | 33827 documents retenus de 2860000 documents traités
# 34.166666666666664 % des documents traités | 33959 documents retenus de 2870000 documents traités
# 34.285714285714285 % des documents traités | 34095 documents retenus de 2880000 documents traités
# 34.404761904761905 % des documents traités | 34200 documents retenus de 2890000 documents traités
# 34.523809523809526 % des documents traités | 34322 documents retenus de 2900000 documents traités
# 34.642857142857146 % des documents traités | 34436 documents retenus de 2910000 documents traités
# 34.76190476190476 % des documents traités | 34565 documents retenus de 2920000 documents traités
# 34.88095238095238 % des documents traités | 34677 documents retenus de 2930000 documents traités
# 35.0 % des documents traités | 34787 documents retenus de 2940000 documents traités
# 35.11904761904762 % des documents traités | 34893 documents retenus de 2950000 documents traités
# 35.23809523809524 % des documents traités | 35004 documents retenus de 2960000 documents traités
# 35.357142857142854 % des documents traités | 35119 documents retenus de 2970000 documents traités
# 35.476190476190474 % des documents traités | 35237 documents retenus de 2980000 documents traités
# 35.595238095238095 % des documents traités | 35351 documents retenus de 2990000 documents traités
# 35.714285714285715 % des documents traités | 35456 documents retenus de 3000000 documents traités
# 35.833333333333336 % des documents traités | 35552 documents retenus de 3010000 documents traités
# 35.95238095238095 % des documents traités | 35664 documents retenus de 3020000 documents traités
# 36.07142857142857 % des documents traités | 35778 documents retenus de 3030000 documents traités
# 36.19047619047619 % des documents traités | 35908 documents retenus de 3040000 documents traités
# 36.30952380952381 % des documents traités | 36024 documents retenus de 3050000 documents traités
# 36.42857142857143 % des documents traités | 36133 documents retenus de 3060000 documents traités
# 36.54761904761905 % des documents traités | 36246 documents retenus de 3070000 documents traités
# 36.666666666666664 % des documents traités | 36371 documents retenus de 3080000 documents traités
# 36.785714285714285 % des documents traités | 36485 documents retenus de 3090000 documents traités
# 36.904761904761905 % des documents traités | 36609 documents retenus de 3100000 documents traités
# 37.023809523809526 % des documents traités | 36718 documents retenus de 3110000 documents traités
# 37.142857142857146 % des documents traités | 36854 documents retenus de 3120000 documents traités
# 37.26190476190476 % des documents traités | 36975 documents retenus de 3130000 documents traités
# 37.38095238095238 % des documents traités | 37083 documents retenus de 3140000 documents traités
# 37.5 % des documents traités | 37203 documents retenus de 3150000 documents traités
# 37.61904761904762 % des documents traités | 37307 documents retenus de 3160000 documents traités
# 37.73809523809524 % des documents traités | 37428 documents retenus de 3170000 documents traités
# 37.857142857142854 % des documents traités | 37551 documents retenus de 3180000 documents traités
# 37.976190476190474 % des documents traités | 37670 documents retenus de 3190000 documents traités
# 38.095238095238095 % des documents traités | 37801 documents retenus de 3200000 documents traités
# 38.214285714285715 % des documents traités | 37916 documents retenus de 3210000 documents traités
# 38.333333333333336 % des documents traités | 38002 documents retenus de 3220000 documents traités
# 38.45238095238095 % des documents traités | 38120 documents retenus de 3230000 documents traités
# 38.57142857142857 % des documents traités | 38272 documents retenus de 3240000 documents traités
# 38.69047619047619 % des documents traités | 38381 documents retenus de 3250000 documents traités
# 38.80952380952381 % des documents traités | 38492 documents retenus de 3260000 documents traités
# 38.92857142857143 % des documents traités | 38627 documents retenus de 3270000 documents traités
# 39.04761904761905 % des documents traités | 38737 documents retenus de 3280000 documents traités
# 39.166666666666664 % des documents traités | 38867 documents retenus de 3290000 documents traités
# 39.285714285714285 % des documents traités | 38967 documents retenus de 3300000 documents traités
# 39.404761904761905 % des documents traités | 39070 documents retenus de 3310000 documents traités
# 39.523809523809526 % des documents traités | 39188 documents retenus de 3320000 documents traités
# 39.642857142857146 % des documents traités | 39301 documents retenus de 3330000 documents traités
# 39.76190476190476 % des documents traités | 39398 documents retenus de 3340000 documents traités
# 39.88095238095238 % des documents traités | 39520 documents retenus de 3350000 documents traités
# 40.0 % des documents traités | 39633 documents retenus de 3360000 documents traités
# 40.11904761904762 % des documents traités | 39744 documents retenus de 3370000 documents traités
# 40.23809523809524 % des documents traités | 39858 documents retenus de 3380000 documents traités
# 40.357142857142854 % des documents traités | 39958 documents retenus de 3390000 documents traités
# 40.476190476190474 % des documents traités | 40078 documents retenus de 3400000 documents traités
# 40.595238095238095 % des documents traités | 40207 documents retenus de 3410000 documents traités
# 40.714285714285715 % des documents traités | 40327 documents retenus de 3420000 documents traités
# 40.833333333333336 % des documents traités | 40433 documents retenus de 3430000 documents traités
# 40.95238095238095 % des documents traités | 40591 documents retenus de 3440000 documents traités
# 41.07142857142857 % des documents traités | 40720 documents retenus de 3450000 documents traités
# 41.19047619047619 % des documents traités | 40825 documents retenus de 3460000 documents traités
# 41.30952380952381 % des documents traités | 40958 documents retenus de 3470000 documents traités
# 41.42857142857143 % des documents traités | 41067 documents retenus de 3480000 documents traités
# 41.54761904761905 % des documents traités | 41188 documents retenus de 3490000 documents traités
# 41.666666666666664 % des documents traités | 41306 documents retenus de 3500000 documents traités
# 41.785714285714285 % des documents traités | 41431 documents retenus de 3510000 documents traités
# 41.904761904761905 % des documents traités | 41580 documents retenus de 3520000 documents traités
# 42.023809523809526 % des documents traités | 41703 documents retenus de 3530000 documents traités
# 42.142857142857146 % des documents traités | 41823 documents retenus de 3540000 documents traités
# 42.26190476190476 % des documents traités | 41951 documents retenus de 3550000 documents traités
# 42.38095238095238 % des documents traités | 42077 documents retenus de 3560000 documents traités
# 42.5 % des documents traités | 42198 documents retenus de 3570000 documents traités
# 42.61904761904762 % des documents traités | 42330 documents retenus de 3580000 documents traités
# 42.73809523809524 % des documents traités | 42448 documents retenus de 3590000 documents traités
# 42.857142857142854 % des documents traités | 42579 documents retenus de 3600000 documents traités
# 42.976190476190474 % des documents traités | 42689 documents retenus de 3610000 documents traités
# 43.095238095238095 % des documents traités | 42790 documents retenus de 3620000 documents traités
# 43.214285714285715 % des documents traités | 42929 documents retenus de 3630000 documents traités
# 43.333333333333336 % des documents traités | 43072 documents retenus de 3640000 documents traités
# 43.45238095238095 % des documents traités | 43178 documents retenus de 3650000 documents traités
# 43.57142857142857 % des documents traités | 43309 documents retenus de 3660000 documents traités
# 43.69047619047619 % des documents traités | 43433 documents retenus de 3670000 documents traités
# 43.80952380952381 % des documents traités | 43536 documents retenus de 3680000 documents traités
# 43.92857142857143 % des documents traités | 43656 documents retenus de 3690000 documents traités
# 44.04761904761905 % des documents traités | 43798 documents retenus de 3700000 documents traités
# 44.166666666666664 % des documents traités | 43921 documents retenus de 3710000 documents traités
# 44.285714285714285 % des documents traités | 44031 documents retenus de 3720000 documents traités
# 44.404761904761905 % des documents traités | 44132 documents retenus de 3730000 documents traités
# 44.523809523809526 % des documents traités | 44228 documents retenus de 3740000 documents traités
# 44.642857142857146 % des documents traités | 44342 documents retenus de 3750000 documents traités
# 44.76190476190476 % des documents traités | 44472 documents retenus de 3760000 documents traités
# 44.88095238095238 % des documents traités | 44608 documents retenus de 3770000 documents traités
# 45.0 % des documents traités | 44724 documents retenus de 3780000 documents traités
# 45.11904761904762 % des documents traités | 44847 documents retenus de 3790000 documents traités
# 45.23809523809524 % des documents traités | 44955 documents retenus de 3800000 documents traités
# 45.357142857142854 % des documents traités | 45048 documents retenus de 3810000 documents traités
# 45.476190476190474 % des documents traités | 45163 documents retenus de 3820000 documents traités
# 45.595238095238095 % des documents traités | 45320 documents retenus de 3830000 documents traités
# 45.714285714285715 % des documents traités | 45440 documents retenus de 3840000 documents traités
# 45.833333333333336 % des documents traités | 45561 documents retenus de 3850000 documents traités
# 45.95238095238095 % des documents traités | 45670 documents retenus de 3860000 documents traités
# 46.07142857142857 % des documents traités | 45776 documents retenus de 3870000 documents traités
# 46.19047619047619 % des documents traités | 45904 documents retenus de 3880000 documents traités
# 46.30952380952381 % des documents traités | 46019 documents retenus de 3890000 documents traités
# 46.42857142857143 % des documents traités | 46144 documents retenus de 3900000 documents traités
# 46.54761904761905 % des documents traités | 46276 documents retenus de 3910000 documents traités
# 46.666666666666664 % des documents traités | 46393 documents retenus de 3920000 documents traités
# 46.785714285714285 % des documents traités | 46496 documents retenus de 3930000 documents traités
# 46.904761904761905 % des documents traités | 46599 documents retenus de 3940000 documents traités
# 47.023809523809526 % des documents traités | 46710 documents retenus de 3950000 documents traités
# 47.142857142857146 % des documents traités | 46830 documents retenus de 3960000 documents traités
# 47.26190476190476 % des documents traités | 46940 documents retenus de 3970000 documents traités
# 47.38095238095238 % des documents traités | 47058 documents retenus de 3980000 documents traités
# 47.5 % des documents traités | 47173 documents retenus de 3990000 documents traités
# 47.61904761904762 % des documents traités | 47302 documents retenus de 4000000 documents traités
# 47.73809523809524 % des documents traités | 47416 documents retenus de 4010000 documents traités
# 47.857142857142854 % des documents traités | 47523 documents retenus de 4020000 documents traités
# 47.976190476190474 % des documents traités | 47693 documents retenus de 4030000 documents traités
# 48.095238095238095 % des documents traités | 47795 documents retenus de 4040000 documents traités
# 48.214285714285715 % des documents traités | 47918 documents retenus de 4050000 documents traités
# 48.333333333333336 % des documents traités | 48024 documents retenus de 4060000 documents traités
# 48.45238095238095 % des documents traités | 48139 documents retenus de 4070000 documents traités
# 48.57142857142857 % des documents traités | 48279 documents retenus de 4080000 documents traités
# 48.69047619047619 % des documents traités | 48377 documents retenus de 4090000 documents traités
# 48.80952380952381 % des documents traités | 48488 documents retenus de 4100000 documents traités
# 48.92857142857143 % des documents traités | 48609 documents retenus de 4110000 documents traités
# 49.04761904761905 % des documents traités | 48705 documents retenus de 4120000 documents traités
# 49.166666666666664 % des documents traités | 48806 documents retenus de 4130000 documents traités
# 49.285714285714285 % des documents traités | 48918 documents retenus de 4140000 documents traités
# 49.404761904761905 % des documents traités | 49015 documents retenus de 4150000 documents traités
# 49.523809523809526 % des documents traités | 49152 documents retenus de 4160000 documents traités
# 49.642857142857146 % des documents traités | 49285 documents retenus de 4170000 documents traités
# 49.76190476190476 % des documents traités | 49385 documents retenus de 4180000 documents traités
# 49.88095238095238 % des documents traités | 49495 documents retenus de 4190000 documents traités
# 50.0 % des documents traités | 49611 documents retenus de 4200000 documents traités
# 50.11904761904762 % des documents traités | 49720 documents retenus de 4210000 documents traités
# 50.23809523809524 % des documents traités | 49869 documents retenus de 4220000 documents traités
# 50.357142857142854 % des documents traités | 50013 documents retenus de 4230000 documents traités
# 50.476190476190474 % des documents traités | 50124 documents retenus de 4240000 documents traités
# 50.595238095238095 % des documents traités | 50221 documents retenus de 4250000 documents traités
# 50.714285714285715 % des documents traités | 50334 documents retenus de 4260000 documents traités
# 50.833333333333336 % des documents traités | 50459 documents retenus de 4270000 documents traités
# 50.95238095238095 % des documents traités | 50556 documents retenus de 4280000 documents traités
# 51.07142857142857 % des documents traités | 50665 documents retenus de 4290000 documents traités
# 51.19047619047619 % des documents traités | 50781 documents retenus de 4300000 documents traités
# 51.30952380952381 % des documents traités | 50913 documents retenus de 4310000 documents traités
# 51.42857142857143 % des documents traités | 51031 documents retenus de 4320000 documents traités
# 51.54761904761905 % des documents traités | 51139 documents retenus de 4330000 documents traités
# 51.666666666666664 % des documents traités | 51252 documents retenus de 4340000 documents traités
# 51.785714285714285 % des documents traités | 51357 documents retenus de 4350000 documents traités
# 51.904761904761905 % des documents traités | 51478 documents retenus de 4360000 documents traités
# 52.023809523809526 % des documents traités | 51591 documents retenus de 4370000 documents traités
# 52.142857142857146 % des documents traités | 51704 documents retenus de 4380000 documents traités
# 52.26190476190476 % des documents traités | 51824 documents retenus de 4390000 documents traités
# 52.38095238095238 % des documents traités | 51958 documents retenus de 4400000 documents traités
# 52.5 % des documents traités | 52062 documents retenus de 4410000 documents traités
# 52.61904761904762 % des documents traités | 52247 documents retenus de 4420000 documents traités
# 52.73809523809524 % des documents traités | 52391 documents retenus de 4430000 documents traités
# 52.857142857142854 % des documents traités | 52509 documents retenus de 4440000 documents traités
# 52.976190476190474 % des documents traités | 52631 documents retenus de 4450000 documents traités
# 53.095238095238095 % des documents traités | 52746 documents retenus de 4460000 documents traités
# 53.214285714285715 % des documents traités | 52888 documents retenus de 4470000 documents traités
# 53.333333333333336 % des documents traités | 53004 documents retenus de 4480000 documents traités
# 53.45238095238095 % des documents traités | 53117 documents retenus de 4490000 documents traités
# 53.57142857142857 % des documents traités | 53235 documents retenus de 4500000 documents traités
# 53.69047619047619 % des documents traités | 53337 documents retenus de 4510000 documents traités
# 53.80952380952381 % des documents traités | 53454 documents retenus de 4520000 documents traités
# 53.92857142857143 % des documents traités | 53563 documents retenus de 4530000 documents traités
# 54.04761904761905 % des documents traités | 53681 documents retenus de 4540000 documents traités
# 54.166666666666664 % des documents traités | 53796 documents retenus de 4550000 documents traités
# 54.285714285714285 % des documents traités | 53918 documents retenus de 4560000 documents traités
# 54.404761904761905 % des documents traités | 54022 documents retenus de 4570000 documents traités
# 54.523809523809526 % des documents traités | 54150 documents retenus de 4580000 documents traités
# 54.642857142857146 % des documents traités | 54243 documents retenus de 4590000 documents traités
# 54.76190476190476 % des documents traités | 54354 documents retenus de 4600000 documents traités
# 54.88095238095238 % des documents traités | 54481 documents retenus de 4610000 documents traités
# 55.0 % des documents traités | 54628 documents retenus de 4620000 documents traités
# 55.11904761904762 % des documents traités | 54758 documents retenus de 4630000 documents traités
# 55.23809523809524 % des documents traités | 54879 documents retenus de 4640000 documents traités
# 55.357142857142854 % des documents traités | 55009 documents retenus de 4650000 documents traités
# 55.476190476190474 % des documents traités | 55128 documents retenus de 4660000 documents traités
# 55.595238095238095 % des documents traités | 55234 documents retenus de 4670000 documents traités
# 55.714285714285715 % des documents traités | 55353 documents retenus de 4680000 documents traités
# 55.833333333333336 % des documents traités | 55470 documents retenus de 4690000 documents traités
# 55.95238095238095 % des documents traités | 55588 documents retenus de 4700000 documents traités
# 56.07142857142857 % des documents traités | 55714 documents retenus de 4710000 documents traités
# 56.19047619047619 % des documents traités | 55817 documents retenus de 4720000 documents traités
# 56.30952380952381 % des documents traités | 55934 documents retenus de 4730000 documents traités
# 56.42857142857143 % des documents traités | 56049 documents retenus de 4740000 documents traités
# 56.54761904761905 % des documents traités | 56166 documents retenus de 4750000 documents traités
# 56.666666666666664 % des documents traités | 56289 documents retenus de 4760000 documents traités
# 56.785714285714285 % des documents traités | 56404 documents retenus de 4770000 documents traités
# 56.904761904761905 % des documents traités | 56529 documents retenus de 4780000 documents traités
# 57.023809523809526 % des documents traités | 56648 documents retenus de 4790000 documents traités
# 57.142857142857146 % des documents traités | 56761 documents retenus de 4800000 documents traités
# 57.26190476190476 % des documents traités | 56914 documents retenus de 4810000 documents traités
# 57.38095238095238 % des documents traités | 57035 documents retenus de 4820000 documents traités
# 57.5 % des documents traités | 57141 documents retenus de 4830000 documents traités
# 57.61904761904762 % des documents traités | 57241 documents retenus de 4840000 documents traités
# 57.73809523809524 % des documents traités | 57361 documents retenus de 4850000 documents traités
# 57.857142857142854 % des documents traités | 57476 documents retenus de 4860000 documents traités
# 57.976190476190474 % des documents traités | 57578 documents retenus de 4870000 documents traités
# 58.095238095238095 % des documents traités | 57689 documents retenus de 4880000 documents traités
# 58.214285714285715 % des documents traités | 57829 documents retenus de 4890000 documents traités
# 58.333333333333336 % des documents traités | 57926 documents retenus de 4900000 documents traités
# 58.45238095238095 % des documents traités | 58044 documents retenus de 4910000 documents traités
# 58.57142857142857 % des documents traités | 58153 documents retenus de 4920000 documents traités
# 58.69047619047619 % des documents traités | 58256 documents retenus de 4930000 documents traités
# 58.80952380952381 % des documents traités | 58384 documents retenus de 4940000 documents traités
# 58.92857142857143 % des documents traités | 58503 documents retenus de 4950000 documents traités
# ...
# 81.19047619047619 % des documents traités | 95584 documents retenus de 6820000 documents traités
# 81.30952380952381 % des documents traités | 95791 documents retenus de 6830000 documents traités
# 81.42857142857143 % des documents traités | 96017 documents retenus de 6840000 documents traités
# 81.54761904761905 % des documents traités | 96237 documents retenus de 6850000 documents traités
# 81.66666666666667 % des documents traités | 96470 documents retenus de 6860000 documents traités
# 81.78571428571429 % des documents traités | 96700 documents retenus de 6870000 documents traités
# 81.9047619047619 % des documents traités | 96919 documents retenus de 6880000 documents traités
# 82.02380952380952 % des documents traités | 97126 documents retenus de 6890000 documents traités
# 82.14285714285714 % des documents traités | 97338 documents retenus de 6900000 documents traités
# 82.26190476190476 % des documents traités | 97530 documents retenus de 6910000 documents traités
# 82.38095238095238 % des documents traités | 97737 documents retenus de 6920000 documents traités
# 82.5 % des documents traités | 97931 documents retenus de 6930000 documents traités
# 82.61904761904762 % des documents traités | 98185 documents retenus de 6940000 documents traités
# 82.73809523809524 % des documents traités | 98428 documents retenus de 6950000 documents traités
# 82.85714285714286 % des documents traités | 98655 documents retenus de 6960000 documents traités
# 82.97619047619048 % des documents traités | 98871 documents retenus de 6970000 documents traités
# 83.0952380952381 % des documents traités | 99083 documents retenus de 6980000 documents traités
# 83.21428571428571 % des documents traités | 99303 documents retenus de 6990000 documents traités
# 83.33333333333333 % des documents traités | 99504 documents retenus de 7000000 documents traités
# 83.45238095238095 % des documents traités | 99713 documents retenus de 7010000 documents traités
# 83.57142857142857 % des documents traités | 99916 documents retenus de 7020000 documents traités
# 83.69047619047619 % des documents traités | 100122 documents retenus de 7030000 documents traités
# 83.80952380952381 % des documents traités | 100339 documents retenus de 7040000 documents traités
# 83.92857142857143 % des documents traités | 100559 documents retenus de 7050000 documents traités
# 84.04761904761905 % des documents traités | 100812 documents retenus de 7060000 documents traités
# 84.16666666666667 % des documents traités | 101042 documents retenus de 7070000 documents traités
# 84.28571428571429 % des documents traités | 101268 documents retenus de 7080000 documents traités
# 84.4047619047619 % des documents traités | 101469 documents retenus de 7090000 documents traités
# 84.52380952380952 % des documents traités | 101682 documents retenus de 7100000 documents traités
# 84.64285714285714 % des documents traités | 101909 documents retenus de 7110000 documents traités
# 84.76190476190476 % des documents traités | 102117 documents retenus de 7120000 documents traités
# 84.88095238095238 % des documents traités | 102328 documents retenus de 7130000 documents traités
# 85.0 % des documents traités | 102566 documents retenus de 7140000 documents traités
# 85.11904761904762 % des documents traités | 102803 documents retenus de 7150000 documents traités
# 85.23809523809524 % des documents traités | 103025 documents retenus de 7160000 documents traités
# 85.35714285714286 % des documents traités | 103222 documents retenus de 7170000 documents traités
# 85.47619047619048 % des documents traités | 103456 documents retenus de 7180000 documents traités
# 85.5952380952381 % des documents traités | 103669 documents retenus de 7190000 documents traités
# 85.71428571428571 % des documents traités | 103883 documents retenus de 7200000 documents traités
# 85.83333333333333 % des documents traités | 104118 documents retenus de 7210000 documents traités
# 85.95238095238095 % des documents traités | 104331 documents retenus de 7220000 documents traités
# 86.07142857142857 % des documents traités | 104535 documents retenus de 7230000 documents traités
# 86.19047619047619 % des documents traités | 104747 documents retenus de 7240000 documents traités
# 86.30952380952381 % des documents traités | 104968 documents retenus de 7250000 documents traités
# 86.42857142857143 % des documents traités | 105173 documents retenus de 7260000 documents traités
# 86.54761904761905 % des documents traités | 105397 documents retenus de 7270000 documents traités
# 86.66666666666667 % des documents traités | 105588 documents retenus de 7280000 documents traités
# 86.78571428571429 % des documents traités | 105812 documents retenus de 7290000 documents traités
# 86.9047619047619 % des documents traités | 106058 documents retenus de 7300000 documents traités
# 87.02380952380952 % des documents traités | 106309 documents retenus de 7310000 documents traités
# 87.14285714285714 % des documents traités | 106536 documents retenus de 7320000 documents traités
# 87.26190476190476 % des documents traités | 106760 documents retenus de 7330000 documents traités
# 87.38095238095238 % des documents traités | 106968 documents retenus de 7340000 documents traités
# 87.5 % des documents traités | 107196 documents retenus de 7350000 documents traités
# 87.61904761904762 % des documents traités | 107395 documents retenus de 7360000 documents traités
# 87.73809523809524 % des documents traités | 107602 documents retenus de 7370000 documents traités
# 87.85714285714286 % des documents traités | 107791 documents retenus de 7380000 documents traités
# 87.97619047619048 % des documents traités | 108023 documents retenus de 7390000 documents traités
# 88.0952380952381 % des documents traités | 108242 documents retenus de 7400000 documents traités
# 88.21428571428571 % des documents traités | 108455 documents retenus de 7410000 documents traités
# 88.33333333333333 % des documents traités | 108705 documents retenus de 7420000 documents traités
# 88.45238095238095 % des documents traités | 108919 documents retenus de 7430000 documents traités
# 88.57142857142857 % des documents traités | 109144 documents retenus de 7440000 documents traités
# 88.69047619047619 % des documents traités | 109370 documents retenus de 7450000 documents traités
# 88.80952380952381 % des documents traités | 109588 documents retenus de 7460000 documents traités
# 88.92857142857143 % des documents traités | 109817 documents retenus de 7470000 documents traités
# 89.04761904761905 % des documents traités | 110010 documents retenus de 7480000 documents traités
# 89.16666666666667 % des documents traités | 110206 documents retenus de 7490000 documents traités
# 89.28571428571429 % des documents traités | 110421 documents retenus de 7500000 documents traités
# 89.4047619047619 % des documents traités | 110646 documents retenus de 7510000 documents traités
# 89.52380952380952 % des documents traités | 110860 documents retenus de 7520000 documents traités
# 89.64285714285714 % des documents traités | 111079 documents retenus de 7530000 documents traités
# 89.76190476190476 % des documents traités | 111325 documents retenus de 7540000 documents traités
# 89.88095238095238 % des documents traités | 111560 documents retenus de 7550000 documents traités
# 90.0 % des documents traités | 111802 documents retenus de 7560000 documents traités
# 90.11904761904762 % des documents traités | 112036 documents retenus de 7570000 documents traités
# 90.23809523809524 % des documents traités | 112275 documents retenus de 7580000 documents traités
# 90.35714285714286 % des documents traités | 112525 documents retenus de 7590000 documents traités
# 90.47619047619048 % des documents traités | 112739 documents retenus de 7600000 documents traités
# 90.5952380952381 % des documents traités | 112967 documents retenus de 7610000 documents traités
# 90.71428571428571 % des documents traités | 113180 documents retenus de 7620000 documents traités
# 90.83333333333333 % des documents traités | 113399 documents retenus de 7630000 documents traités
# 90.95238095238095 % des documents traités | 113601 documents retenus de 7640000 documents traités
# 91.07142857142857 % des documents traités | 113809 documents retenus de 7650000 documents traités
# 91.19047619047619 % des documents traités | 114066 documents retenus de 7660000 documents traités
# 91.30952380952381 % des documents traités | 114305 documents retenus de 7670000 documents traités
# 91.42857142857143 % des documents traités | 114521 documents retenus de 7680000 documents traités
# 91.54761904761905 % des documents traités | 114747 documents retenus de 7690000 documents traités
# 91.66666666666667 % des documents traités | 114967 documents retenus de 7700000 documents traités
# 91.78571428571429 % des documents traités | 115198 documents retenus de 7710000 documents traités
# 91.9047619047619 % des documents traités | 115425 documents retenus de 7720000 documents traités
# 92.02380952380952 % des documents traités | 115632 documents retenus de 7730000 documents traités
# 92.14285714285714 % des documents traités | 115868 documents retenus de 7740000 documents traités
# 92.26190476190476 % des documents traités | 116088 documents retenus de 7750000 documents traités
# 92.38095238095238 % des documents traités | 116294 documents retenus de 7760000 documents traités
# 92.5 % des documents traités | 116473 documents retenus de 7770000 documents traités
# 92.61904761904762 % des documents traités | 116723 documents retenus de 7780000 documents traités
# 92.73809523809524 % des documents traités | 116948 documents retenus de 7790000 documents traités
# 92.85714285714286 % des documents traités | 117161 documents retenus de 7800000 documents traités
# 92.97619047619048 % des documents traités | 117401 documents retenus de 7810000 documents traités
# 93.0952380952381 % des documents traités | 117618 documents retenus de 7820000 documents traités
# 93.21428571428571 % des documents traités | 117863 documents retenus de 7830000 documents traités
# 93.33333333333333 % des documents traités | 118079 documents retenus de 7840000 documents traités
# 93.45238095238095 % des documents traités | 118330 documents retenus de 7850000 documents traités
# 93.57142857142857 % des documents traités | 118547 documents retenus de 7860000 documents traités
# 93.69047619047619 % des documents traités | 118770 documents retenus de 7870000 documents traités
# 93.80952380952381 % des documents traités | 118983 documents retenus de 7880000 documents traités
# 93.92857142857143 % des documents traités | 119218 documents retenus de 7890000 documents traités
# 94.04761904761905 % des documents traités | 119427 documents retenus de 7900000 documents traités
# 94.16666666666667 % des documents traités | 119661 documents retenus de 7910000 documents traités
# 94.28571428571429 % des documents traités | 119872 documents retenus de 7920000 documents traités
# 94.4047619047619 % des documents traités | 120075 documents retenus de 7930000 documents traités
# 94.52380952380952 % des documents traités | 120294 documents retenus de 7940000 documents traités
# 94.64285714285714 % des documents traités | 120511 documents retenus de 7950000 documents traités
# 94.76190476190476 % des documents traités | 120702 documents retenus de 7960000 documents traités
# 94.88095238095238 % des documents traités | 120901 documents retenus de 7970000 documents traités
# 95.0 % des documents traités | 121111 documents retenus de 7980000 documents traités
# 95.11904761904762 % des documents traités | 121322 documents retenus de 7990000 documents traités
# 95.23809523809524 % des documents traités | 121528 documents retenus de 8000000 documents traités
# 95.35714285714286 % des documents traités | 121762 documents retenus de 8010000 documents traités
# 95.47619047619048 % des documents traités | 121965 documents retenus de 8020000 documents traités
# 95.5952380952381 % des documents traités | 122166 documents retenus de 8030000 documents traités
# 95.71428571428571 % des documents traités | 122404 documents retenus de 8040000 documents traités
# 95.83333333333333 % des documents traités | 122656 documents retenus de 8050000 documents traités
# 95.95238095238095 % des documents traités | 122877 documents retenus de 8060000 documents traités
# 96.07142857142857 % des documents traités | 123077 documents retenus de 8070000 documents traités
# 96.19047619047619 % des documents traités | 123295 documents retenus de 8080000 documents traités
# 96.30952380952381 % des documents traités | 123506 documents retenus de 8090000 documents traités
# 96.42857142857143 % des documents traités | 123739 documents retenus de 8100000 documents traités
# 96.54761904761905 % des documents traités | 123965 documents retenus de 8110000 documents traités
# 96.66666666666667 % des documents traités | 124183 documents retenus de 8120000 documents traités
# 96.78571428571429 % des documents traités | 124412 documents retenus de 8130000 documents traités
# 96.9047619047619 % des documents traités | 124627 documents retenus de 8140000 documents traités
# 97.02380952380952 % des documents traités | 124853 documents retenus de 8150000 documents traités
# 97.14285714285714 % des documents traités | 125078 documents retenus de 8160000 documents traités
# 97.26190476190476 % des documents traités | 125318 documents retenus de 8170000 documents traités
# 97.38095238095238 % des documents traités | 125552 documents retenus de 8180000 documents traités
# 97.5 % des documents traités | 125745 documents retenus de 8190000 documents traités
# 97.61904761904762 % des documents traités | 125964 documents retenus de 8200000 documents traités
# 97.73809523809524 % des documents traités | 126166 documents retenus de 8210000 documents traités
# 97.85714285714286 % des documents traités | 126342 documents retenus de 8220000 documents traités
# 97.97619047619048 % des documents traités | 126552 documents retenus de 8230000 documents traités
# 98.0952380952381 % des documents traités | 126772 documents retenus de 8240000 documents traités
# 98.21428571428571 % des documents traités | 127006 documents retenus de 8250000 documents traités
# 98.33333333333333 % des documents traités | 127229 documents retenus de 8260000 documents traités
# 98.45238095238095 % des documents traités | 127428 documents retenus de 8270000 documents traités
# 98.57142857142857 % des documents traités | 127630 documents retenus de 8280000 documents traités
# 98.69047619047619 % des documents traités | 127821 documents retenus de 8290000 documents traités
# 98.80952380952381 % des documents traités | 128032 documents retenus de 8300000 documents traités
# 98.92857142857143 % des documents traités | 128171 documents retenus de 8310000 documents traités
# 99.04761904761905 % des documents traités | 128260 documents retenus de 8320000 documents traités
# 99.16666666666667 % des documents traités | 128347 documents retenus de 8330000 documents traités
# 99.28571428571429 % des documents traités | 128445 documents retenus de 8340000 documents traités
# 99.4047619047619 % des documents traités | 128532 documents retenus de 8350000 documents traités
# 99.52380952380952 % des documents traités | 128625 documents retenus de 8360000 documents traités
# 99.64285714285714 % des documents traités | 128721 documents retenus de 8370000 documents traités
# 99.76190476190476 % des documents traités | 128817 documents retenus de 8380000 documents traités
# 99.88095238095238 % des documents traités | 128911 documents retenus de 8390000 documents traités
# 100.0 % des documents traités | 129029 documents retenus de 8400000 documents traités
# 100.11904761904762 % des documents traités | 129119 documents retenus de 8410000 documents traités
# 100.23809523809524 % des documents traités | 129213 documents retenus de 8420000 documents traités
# Total documents traités : 8421456 | Documents indexés : 129231
# 19:45:30.066 [main] WARN org.terrier.structures.indexing.Indexer -- Indexed 770 empty documents
# Indexation terminée : <org.terrier.querying.IndexRef at 0x2315bdbaed0 jclass=org/terrier/querying/IndexRef jself=<LocalRef obj=0x3bf5045a at 0x231a26ff030>>

# %% [markdown]
# ## A-2: updating qrels and queries to correspond the new doc collection

# %%
qrels_df = pd.read_csv(
    "data/qrels.test", sep=" ",
    names=["qid","zero","docno","relevance"], dtype=str
)
display(qrels_df.head())

queries_df = pd.read_json("data/queries.test.jsonl", lines=True)
queries_df = queries_df.rename(columns={"query_id": "qid", "text": "query"})
queries_df["qid"] = queries_df["qid"].astype(str)
display(queries_df.head())
# Out:
#    qid zero             docno relevance
# 0  263    0  1990028700044315         3
# 1  263    0  1990047100022016         3
# 2  263    0  1990061800001166         3
# 3  263    0  1990075200077466         3
# 4  263    0  1990083600000244         3
#    qid                    query
# 0  263           calcio mercato
# 1  326         cotto e mangiato
# 2  381  lavatrici ad ultrasuoni
# 3  480         giallo zafferano
# 4  515              stipendi pa

# %%
print(f"{len(kept_docnos)} docno récupérés de l'index (reproduction du filtre)")
#with open("data/kept_docnos.txt", "w") as f:
with open("data/kept_docnos.txt", "w") as f:
	for docno in kept_docnos:
		f.write(f"{docno}\n")
# Out:
# 129232 docno récupérés de l'index (reproduction du filtre)

# %%
# i'm updating qrels
qrels_df = qrels_df[qrels_df["docno"].isin(kept_docnos)]
qrels_df["relevance"] = qrels_df["relevance"].astype(int)
qrels_df.to_csv("data/kept_qrels.csv", index=False)
queries_df = queries_df[queries_df["qid"].isin(qrels_df["qid"])]
queries_df.to_csv("data/kept_queries.csv", index=False)
print(f"{len(qrels_df)}  qrel saved")
print(f"{len(queries_df)}  queries saved")
# Out:
# 594  qrel saved
# 234  queries saved

# %%
qrels = {(row["qid"], row["docno"]): row["relevance"] for _, row in qrels_df.iterrows()}
print(f"Qrels :", qrels)
# Out:
# Qrels : {('594', '1990131000007252'): 3, ('680', '1990018100303455'): 3, ('680', '1990089200000157'): 1, ('1168', '1990083002539704'): 4, ('1327', '1990119500892034'): 3, ('2217', '1990022900501496'): 4, ('2217', '1990084602539290'): 4, ('3615', '1990052900015840'): 1, ('3873', '1990116900679458'): 1, ('4797', '1990078801259321'): 3, ('4797', '1990139400016103'): 1, ('4933', '1990071602540234'): 1, ('4933', '1990093402538496'): 1, ('4933', '1990097202541632'): 1, ('4933', '1990106602544080'): 1, ('4933', '1990121902541574'): 1, ('4933', '1990137800453992'): 1, ('4933', '1990155902534081'): 1, ('5061', '1990128400160708'): 1, ('5061', '1990129302540757'): 4, ('5262', '1990023000000837'): 3, ('5262', '1990040601523702'): 3, ('5262', '1990055000702701'): 1, ('5262', '1990060001646608'): 1, ('5262', '1990128700924146'): 1, ('6534', '1990022601270316'): 1, ('7525', '1990133802538127'): 3, ('7684', '1990126700174684'): 3, ('7694', '1990069802543421'): 1, ('7694', '1990091902539049'): 1, ('7694', '1990098902541296'): 1, ('7717', '1990065101258371'): 1, ('7722', '1990046902540640'): 3, ('7722', '1990064000007186'): 3, ('7722', '1990089800006156'): 3, ('7722', '1990140002539530'): 3, ('7798', '1990034700001173'): 3, ('8009', '1990067302543979'): 3, ('8179', '1990108700004313'): 3, ('8992', '1990025002540130'): 1, ('8992', '1990124602542501'): 3, ('8992', '1990125602538329'): 2, ('10348', '1990023601263299'): 3, ('10348', '1990074901086410'): 3, ('10348', '1990088002539771'): 3, ('10348', '1990131202543313'): 3, ('10353', '1990087102541738'): 3, ('10353', '1990103402541613'): 3, ('10353', '1990120102542352'): 1, ('10360', '1990045602543165'): 3, ('10360', '1990121902540872'): 3, ('10360', '1990128602539453'): 1, ('10360', '1990136502541400'): 1, ('10632', '1990085602543100'): 3, ('10906', '1990109002490790'): 1, ('11235', '1990130302537364'): 3, ('11318', '1990158202501377'): 3, ('11425', '1990021002541435'): 1, ('11425', '1990089402503392'): 3, ('11425', '1990139902540582'): 1, ('11425', '1990142700007831'): 1, ('11571', '1990072902541684'): 1, ('11571', '1990087802543805'): 1, ('12531', '1990147702540684'): 4, ('12646', '1990116902540251'): 3, ('12646', '1990118702491382'): 1, ('13571', '1990070000000153'): 3, ('14881', '1990044000048914'): 3, ('15268', '1990042302540645'): 3, ('15268', '1990077102540195'): 3, ('15268', '1990151602538997'): 3, ('16647', '1990063601430560'): 3, ('17624', '1990069000000520'): 1, ('18471', '1990034902539539'): 1, ('18471', '1990150501068621'): 1, ('18516', '1990122200076852'): 1, ('19356', '1990138402540870'): 2, ('19582', '1990011400272056'): 1, ('19582', '1990113402542873'): 1, ('19890', '1990041802541449'): 1, ('19890', '1990051302544114'): 1, ('19890', '1990086902545710'): 1, ('19890', '1990119400729010'): 2, ('20313', '1990124302542725'): 1, ('20370', '1990023002541117'): 1, ('20452', '1990031300035430'): 1, ('21217', '1990010502540485'): 1, ('21217', '1990032301438824'): 3, ('21217', '1990037402542680'): 3, ('21217', '1990037802539681'): 1, ('21217', '1990080700024938'): 1, ('21217', '1990124302541096'): 2, ('21217', '1990126000311961'): 1, ('21517', '1990028002539857'): 1, ('22230', '1990011002416810'): 3, ('22230', '1990021802540033'): 2, ('22230', '1990060802542370'): 1, ('22230', '1990073702542426'): 1, ('22230', '1990147802541842'): 1, ('22337', '1990096302541932'): 1, ('22337', '1990145600038256'): 3, ('23279', '1990095302540878'): 4, ('23279', '1990127202543292'): 1, ('23279', '1990129802543192'): 1, ('23867', '1990110002543439'): 2, ('24025', '1990015602542446'): 1, ('25903', '1990119600001361'): 2, ('26016', '1990045302539969'): 3, ('26016', '1990065000141831'): 1, ('26016', '1990073402539862'): 1, ('26016', '1990080800510170'): 3, ('26016', '1990117602542165'): 4, ('26016', '1990143000473412'): 1, ('26393', '1990104102543623'): 2, ('26600', '1990158902541122'): 1, ('26700', '1990071902544094'): 1, ('26878', '1990078502541420'): 4, ('27335', '1990040402013583'): 4, ('27335', '1990080100000 ...

# %% [markdown]
# # B - Stopping strategies

# %% [markdown]
# ## B-0 extract hard and easy queries

# %%
index = pt.IndexFactory.of("index/data_1.properties")
pl2 = pt.terrier.Retriever(index, wmodel="PL2", num_results =1000, metadata=['docno'])
hard_query_ranking  = pl2.transform(queries_df)
avg_scores = (
    hard_query_ranking
    .groupby(["qid", "query"])["score"]
    .mean()
    .reset_index(name="avg_score")
)
hardest = avg_scores.sort_values("avg_score", ascending=True).head(50)
hardest[["qid", "query"]].to_csv("data/hard_queries.csv", index=False)
easiest = avg_scores.sort_values("avg_score", ascending=False).head(50)
easiest[["qid", "query"]].to_csv("data/easy_queries.csv", index=False)
display(hardest.shape, hardest.head(10))
# Out:
# (50, 3)
#        qid                     query  avg_score
# 75    3873       sinonimi e contrari   1.875155
# 17   17624          chianciano terme   2.887562
# 13   13571             tende a rullo   2.909435
# 97   42269            yasmine bleeth   2.910354
# 92   41683              tiffany toth   3.055847
# 165  66567           rizzoli e isles   3.109468
# 66   36959             canyon aeroad   3.163643
# 152  63485               pharma news   3.189995
# 83   39334              lindsey vonn   3.293854
# 181  73055  madagascar swamp warbler   3.293873

# %% [markdown]
# ## B-1 initial ranking

# %%
index = pt.IndexFactory.of("index/data_1.properties")
pl2 = pt.terrier.Retriever(index, wmodel="PL2", num_results =100, metadata=['docno', 'text'])
initial_ranking  = pl2.transform(queries_df)

# %%
initial_ranking.head(10)
# Out:
#    qid   docid             docno  \
# 0  594  129013  1990131000007252
# 1  594   56684  1990012301082193
# 2  594   60702  1990066102541092
# 3  594  128971  1990126700174684
# 4  594   53153  1990012102481006
# 5  594   98506  1990011301631960
# 6  594   41143  1990011602091449
# 7  594  100768  1990011401264059
# 8  594   55138  1990012202023484
# 9  594    1477  1990010001436487
#
#                                                 text  rank      score  \
# 0                    Video sportivi - Sport Mediaset     0  12.928206
# 1  nuova fiction mediaset | Spindle\n\nnuova fict...     1  11.860954
# 2  Video Amici: Francesco e Anbeta - You never ca...     2  11.591290
# 3  Video Tgcom24: Francesco Nuti da Barbara D'Urs...     3  11.494154
# 4  Cannes: Lionsgate Intl. Rolls Out ‘Marrowbone’...     4  10.046203
# 5  Prisa confirms appeal against Spanish DTT awar...     5   9.050257
# 6  Shroud of the Avatar Streaming on a Nexus Play...     6   8.132299
# 7  New Ooyala Study Shows Mobile Audiences Matter...     7   8.037220
# 8  Mancini: Inter’s loss to Lazio was stupid | Fo...     8   7.675206
# 9  Sportpesa » Chelsea will meet the agent of Eze...     9   7.559798
#
#             query
# 0  mediaset video
# 1  mediaset video
# 2  mediaset video
# 3  mediaset video
# 4  mediaset video
# 5  mediaset video
# 6  mediaset video
# 7  mediaset video
# 8  mediaset video
# 9  mediaset video

# %%
pt.Evaluate(initial_ranking, qrels_df, metrics=['map', "ndcg", "P"], perquery=False)
# Out:
# {'map': 0.6592542543732097,
#  'ndcg': 0.7072426270693265,
#  'P@5': 0.3324786324786329,
#  'P@10': 0.20085470085470108,
#  'P@15': 0.14358974358974338,
#  'P@20': 0.11047008547008562,
#  'P@30': 0.0769230769230769,
#  'P@100': 0.023974358974358918,
#  'P@200': 0.011987179487179459,
#  'P@500': 0.004794871794871798,
#  'P@1000': 0.002397435897435899}

# %% [markdown]
# ## B-2 stopping transformations

# %%
meta = index.getMetaIndex()

def get_text_from_index(docid):
    return meta.getItem("text", int(docid))

# %%
qrels = {
	(str(row.qid), str(row.docno)): int(row.relevance)
	for row in qrels_df.itertuples()
}

def apply_ss1(ranking, qid, x1):
	return ranking.iloc[:x1]

def apply_ss2(ranking, qid, x2):
	non_rel = 0
	kept_idx = []
	for idx, row in ranking.iterrows():
		kept_idx.append(idx)
		# On récupère la pertinence via le dict ; défaut 0 si absent
		rel = qrels.get((str(qid), str(row.docno)), 0)
		if rel == 0:
			non_rel += 1
		if non_rel >= x2:
			break
	return ranking.loc[kept_idx]

def apply_ss3(ranking, qid, x3):
	consec = 0
	kept_idx = []
	for idx, row in ranking.iterrows():
		kept_idx.append(idx)
		rel = qrels.get((str(qid), str(row.docno)), 0)
		if rel == 0:
			consec += 1
		else:
			consec = 0
		if consec >= x3:
			break
	return ranking.loc[kept_idx]


def apply_ss4(ranking, qid, x4):
	seen_terms = set()
	stop_at = None
	for idx, row in ranking.iterrows():
		terms_curr = set(row["text"].split())
		overlap = len(terms_curr & seen_terms) / max(len(terms_curr), 1)
		if overlap > x4:
			stop_at = idx
			break
		seen_terms |= terms_curr
	if stop_at is None:
		return ranking.copy()
	return ranking.loc[:stop_at]
from collections import Counter
import math

def apply_ss5(ranking, qid, x5):
	seen_counts = Counter()
	total_seen  = 0
	stop_at     = None

	for idx_row, row in ranking.iterrows():
		full_text  = get_text_from_index(row["docid"])
		words_curr = full_text.split()
		count_curr = Counter(words_curr)
		total_curr = sum(count_curr.values())
		P_curr     = {w: c/total_curr for w, c in count_curr.items()}
		P_prev = {w: seen_counts[w]/total_seen for w in seen_counts} if total_seen>0 else {}
		kl = sum(p * math.log(p / P_prev.get(w, 1e-15)) for w, p in P_curr.items())
		if kl < x5:
			stop_at = idx_row
			break
		seen_counts.update(count_curr)
		total_seen  += total_curr
	return ranking if stop_at is None else ranking.loc[:stop_at]


def apply_ss6(ranking, qid, x6, td=1.0, tq=2.0):
	cum_gain = 0.0
	stop_at = None
	for rank, row in ranking.iterrows():
		rel = qrels.get((str(qid), str(row.docno)), 0)
		cum_gain += (2**rel-1) / math.log2(rank + 2) 
		cost = rank * td + tq
		rate = cum_gain / cost

		if rank >= 4.0 and rate < x6:  # commencer à estimer après 2 documents
			stop_at = rank
			break

	if stop_at is None:
		return ranking.copy()
	return ranking.iloc[:stop_at+1]

# %% [markdown]
# ## B-2 Le gain cumulatif moyen

# %%
def dcg_at_k(rels):
    return sum((2**rel -1)/(math.log2(idx+2)) for idx, rel in enumerate(rels))

def cg_at_k(rels):
    return sum(rels)

def average_dcg_and_avr_depth(stopping_function, x=0, initial_ranking=initial_ranking):
    total_dcg = 0.0
    total_depth = 0
    for qid in queries_df["qid"]:
        subrank = initial_ranking[initial_ranking["qid"] == qid] \
                    .sort_values("score", ascending=False)
        stopped = stopping_function(subrank, qid, x)
        docnos = stopped["docno"].tolist()
        relevs = [qrels.get((qid, docno)) for docno in docnos] # make zero if not found
        relevs = [0 if rel is None else rel for rel in relevs]
        ideal = sorted(relevs, reverse=True)
        total_dcg   += dcg_at_k(relevs) #/(dcg_at_k(ideal)+1e-15)
        total_depth += len(docnos)
    return total_dcg / len(queries_df), total_depth / len(queries_df)

# %%
import json
import numpy as np
from tqdm import tqdm

x1_values = np.concatenate((np.arange(1, 20, 1), np.arange(25, 50, 5)))
x2_values = x1_values
x3_values = x1_values
x4_values = np.arange(0.1, 1.0, 0.05)
x5_values = np.arange(3.0, 8.1, 0.5)
x6_values = np.arange(0.002, 0.03, 0.001)

N_RUNS = 3

raw = {
    "SS1": {"x": x1_values, "gains": [],  "depths": []},
    "SS2": {"x": x2_values, "gains": [],  "depths": []},
    "SS3": {"x": x3_values, "gains": [],  "depths": []},
    "SS4": {"x": x4_values, "gains": [],  "depths": []},
    "SS5": {"x": x5_values, "gains": [],  "depths": []}
}

strategies = {
	"SS1": apply_ss1,
    "SS2": apply_ss2,
    "SS3": apply_ss3,
    "SS4": apply_ss4,
    "SS5": apply_ss5
}

for run in range(N_RUNS):
    print(f"=== Run {run+1}/{N_RUNS} ===")
    for name, func in strategies.items():
        x_vals = raw[name]["x"]
        gains_run  = []
        depths_run = []
        for x in tqdm(x_vals, desc=name):
            cg, dp = average_dcg_and_avr_depth(func, x=x, initial_ranking=initial_ranking)
            gains_run.append(cg)
            depths_run.append(dp)
        raw[name]["gains"].append(gains_run)
        raw[name]["depths"].append(depths_run)

results = {}
for name in strategies:
    arr_gains  = np.array(raw[name]["gains"])   # shape (N_RUNS, len(x))
    arr_depths = np.array(raw[name]["depths"])
    mean_gains  = arr_gains.mean(axis=0).tolist()
    mean_depths = arr_depths.mean(axis=0).tolist()
    results[name] = {
        "x":   raw[name]["x"].tolist(),
        "gains":  mean_gains,
        "depths": mean_depths
    }

with open("results/avg_full_stopping_strategies_results_final.json", "w") as fp:
    json.dump(results, fp, indent=4)
# Out:
# === Run 1/3 ===
# SS1: 100%|██████████| 24/24 [00:16<00:00,  1.48it/s]
# SS2: 100%|██████████| 24/24 [00:27<00:00,  1.14s/it]
# SS3: 100%|██████████| 24/24 [00:28<00:00,  1.19s/it]
# SS4: 100%|██████████| 18/18 [00:29<00:00,  1.66s/it]
# SS5: 100%|██████████| 11/11 [02:44<00:00, 14.98s/it]
# === Run 2/3 ===
# SS1: 100%|██████████| 24/24 [00:17<00:00,  1.38it/s]
# SS2: 100%|██████████| 24/24 [00:27<00:00,  1.16s/it]
# SS3: 100%|██████████| 24/24 [00:27<00:00,  1.15s/it]
# SS4: 100%|██████████| 18/18 [00:28<00:00,  1.58s/it]
# SS5: 100%|██████████| 11/11 [03:13<00:00, 17.61s/it]
# === Run 3/3 ===
# SS1: 100%|██████████| 24/24 [00:13<00:00,  1.79it/s]
# SS2: 100%|██████████| 24/24 [00:21<00:00,  1.12it/s]
# SS3: 100%|██████████| 24/24 [00:24<00:00,  1.03s/it]
# SS4: 100%|██████████| 18/18 [00:25<00:00,  1.42s/it]
# SS5: 100%|██████████| 11/11 [05:28<00:00, 29.89s/it]

# %%
def plot(file="results/full_hard_stopping_strategies_results.json", title="title"):
	import matplotlib.pyplot as plt
	plt.figure(figsize=(5, 5))
	import seaborn as sns
	sns.set_style("darkgrid")
	with open(file, "r") as f:
		data = json.load(f)
		ss1_depths = data["SS1"]["depths"]
		ss1_gains = data["SS1"]["gains"]
		ss2_depths = data["SS2"]["depths"]	
		ss2_gains = data["SS2"]["gains"]
		ss3_depths = data["SS3"]["depths"]
		ss3_gains = data["SS3"]["gains"]
		ss4_depths = data["SS4"]["depths"]
		ss4_gains = data["SS4"]["gains"]
		ss5_depths = data["SS5"]["depths"]
		ss5_gains = data["SS5"]["gains"]
	

	sns.lineplot(x=ss1_depths, y=ss1_gains, label="SS1", marker='o')
	sns.lineplot(x=ss2_depths, y=ss2_gains, label="SS2", marker='*')
	sns.lineplot(x=ss3_depths, y=ss3_gains, label="SS3", marker='x')
	sns.lineplot(x=ss4_depths, y=ss4_gains, label="SS4", marker='^')
	sns.lineplot(x=ss5_depths, y=ss5_gains, label="SS5", marker='s')
	plt.xlabel("Mean Depth/Query")
	plt.ylabel("Mean CG")
	plt.title(title)
	plt.legend()
	plt.show()

# %%
plot("results/avg_full_stopping_strategies_results_final.json", title = "Stopping Strategies on Istella22 using all queries")

# %% [markdown]
# ## B-3 REDO with hard queries

# %%
hard_queries_df = pd.read_csv("data/hard_queries.csv")
index = pt.IndexFactory.of("index/data_1.properties")
pl2 = pt.terrier.Retriever(index, wmodel="PL2", num_results =100, metadata=['docno', 'text'])
initial_ranking_hard  = pl2.transform(hard_queries_df)

# %%
pt.Evaluate(initial_ranking_hard, qrels_df, metrics=['map', "ndcg", "P"], perquery=False)
# Out:
# {'map': 0.15294000282133258,
#  'ndcg': 0.16485916881975543,
#  'P@5': 0.0735042735042735,
#  'P@10': 0.04230769230769229,
#  'P@15': 0.029914529914529926,
#  'P@20': 0.022435897435897422,
#  'P@30': 0.01538461538461539,
#  'P@100': 0.004700854700854703,
#  'P@200': 0.0023504273504273516,
#  'P@500': 0.0009401709401709405,
#  'P@1000': 0.00047008547008547025}

# %%
import json
import numpy as np
from tqdm import tqdm

x1_values = np.concatenate((np.arange(1, 20, 1), np.arange(25, 50, 5)))
x2_values = x1_values
x3_values = x1_values
x4_values = np.arange(0.1, 1.0, 0.05)
x5_values = np.arange(3.0, 8.1, 0.5)
x6_values = np.arange(0.002, 0.03, 0.002)

N_RUNS = 3

raw = {
    "SS1": {"x": x1_values, "gains": [],  "depths": []},
    "SS2": {"x": x2_values, "gains": [],  "depths": []},
    "SS3": {"x": x3_values, "gains": [],  "depths": []},
    "SS4": {"x": x4_values, "gains": [],  "depths": []},
    "SS5": {"x": x5_values, "gains": [],  "depths": []}
    }

strategies = {
    "SS1": apply_ss1,
    "SS2": apply_ss2,
    "SS3": apply_ss3,
    "SS4": apply_ss4,
    "SS5": apply_ss5
    }

for run in range(N_RUNS):
    print(f"=== Run {run+1}/{N_RUNS} ===")
    for name, func in strategies.items():
        x_vals = raw[name]["x"]
        gains_run  = []
        depths_run = []
        for x in tqdm(x_vals, desc=name):
            cg, dp = average_dcg_and_avr_depth(func, x=x, initial_ranking=initial_ranking_hard)
            gains_run.append(cg)
            depths_run.append(dp)
        raw[name]["gains"].append(gains_run)
        raw[name]["depths"].append(depths_run)

results = {}
for name in strategies:
    arr_gains  = np.array(raw[name]["gains"])   # shape (N_RUNS, len(x))
    arr_depths = np.array(raw[name]["depths"])
    mean_gains  = arr_gains.mean(axis=0).tolist()
    mean_depths = arr_depths.mean(axis=0).tolist()
    results[name] = {
        "x":   raw[name]["x"].tolist(),
        "gains":  mean_gains,
        "depths": mean_depths
    }

with open("results/avg_hard_full_stopping_strategies_results_final.json", "w") as fp:
    json.dump(results, fp, indent=4)
# Out:
# === Run 1/3 ===
# SS1: 100%|██████████| 24/24 [00:07<00:00,  3.29it/s]
# SS2: 100%|██████████| 24/24 [00:11<00:00,  2.03it/s]
# SS3: 100%|██████████| 24/24 [00:11<00:00,  2.07it/s]
# SS4: 100%|██████████| 18/18 [00:10<00:00,  1.75it/s]
# SS5: 100%|██████████| 11/11 [00:48<00:00,  4.37s/it]
# === Run 2/3 ===
# SS1: 100%|██████████| 24/24 [00:07<00:00,  3.04it/s]
# SS2: 100%|██████████| 24/24 [00:11<00:00,  2.07it/s]
# SS3: 100%|██████████| 24/24 [00:12<00:00,  1.97it/s]
# SS4: 100%|██████████| 18/18 [00:11<00:00,  1.55it/s]
# SS5: 100%|██████████| 11/11 [00:52<00:00,  4.78s/it]
# === Run 3/3 ===
# SS1: 100%|██████████| 24/24 [00:07<00:00,  3.16it/s]
# SS2: 100%|██████████| 24/24 [00:11<00:00,  2.07it/s]
# SS3: 100%|██████████| 24/24 [00:12<00:00,  1.88it/s]
# SS4: 100%|██████████| 18/18 [00:10<00:00,  1.67it/s]
# SS5: 100%|██████████| 11/11 [00:49<00:00,  4.51s/it]

# %%
plot("results/avg_hard_full_stopping_strategies_results_final.json", title = "Stopping Strategies on Istella22 using hard queries")

# %% [markdown]
# ## B-4 REDO with easy queries

# %%
easy_queries_df = pd.read_csv("data/easy_queries.csv")
index = pt.IndexFactory.of("index/data_1.properties")
pl2 = pt.terrier.Retriever(index, wmodel="PL2", num_results =100, metadata=['docno', 'text'])
initial_ranking_easy  = pl2.transform(easy_queries_df)

# %%
pt.Evaluate(initial_ranking_easy, qrels_df, metrics=['map', "ndcg", "P"], perquery=False)
# Out:
# {'map': 0.16586629528572638,
#  'ndcg': 0.16784325516237625,
#  'P@5': 0.09145299145299142,
#  'P@10': 0.05598290598290596,
#  'P@15': 0.039031339031339034,
#  'P@20': 0.030341880341880338,
#  'P@30': 0.0207977207977208,
#  'P@100': 0.006367521367521371,
#  'P@200': 0.0031837606837606855,
#  'P@500': 0.001273504273504274,
#  'P@1000': 0.000636752136752137}

# %%
import json
import numpy as np
from tqdm import tqdm

x1_values = np.concatenate((np.arange(1, 20, 1), np.arange(20, 50, 4)))
x2_values = x1_values
x3_values = x1_values
x4_values = np.arange(0.1, 1.0, 0.05)
x5_values = np.arange(3.0, 10, 0.5)
x6_values = np.arange(0.0001, 0.06, 0.002)

N_RUNS = 3

raw = {
    "SS1": {"x": x1_values, "gains": [],  "depths": []},
    "SS2": {"x": x2_values, "gains": [],  "depths": []},
    "SS3": {"x": x3_values, "gains": [],  "depths": []},
    "SS4": {"x": x4_values, "gains": [],  "depths": []},
    "SS5": {"x": x5_values, "gains": [],  "depths": []}
    }

strategies = {
    "SS1": apply_ss1,
    "SS2": apply_ss2,
    "SS3": apply_ss3,
    "SS4": apply_ss4,
    "SS5": apply_ss5
    }

for run in range(N_RUNS):
    print(f"=== Run {run+1}/{N_RUNS} ===")
    for name, func in strategies.items():
        x_vals = raw[name]["x"]
        gains_run  = []
        depths_run = []
        for x in tqdm(x_vals, desc=name):
            cg, dp = average_dcg_and_avr_depth(func, x=x, initial_ranking=initial_ranking_easy)
            gains_run.append(cg)
            depths_run.append(dp)
        raw[name]["gains"].append(gains_run)
        raw[name]["depths"].append(depths_run)

results = {}
for name in strategies:
    arr_gains  = np.array(raw[name]["gains"])   # shape (N_RUNS, len(x))
    arr_depths = np.array(raw[name]["depths"])
    mean_gains  = arr_gains.mean(axis=0).tolist()
    mean_depths = arr_depths.mean(axis=0).tolist()
    results[name] = {
        "x":   raw[name]["x"].tolist(),
        "gains":  mean_gains,
        "depths": mean_depths
    }

with open("results/avg_easy_full_stopping_strategies_results_final.json", "w") as fp:
    json.dump(results, fp, indent=4)
# Out:
# === Run 1/3 ===
# SS1: 100%|██████████| 24/24 [00:06<00:00,  3.48it/s]
# SS2: 100%|██████████| 24/24 [00:10<00:00,  2.39it/s]
# SS3: 100%|██████████| 24/24 [00:09<00:00,  2.65it/s]
# SS4: 100%|██████████| 18/18 [00:17<00:00,  1.06it/s]
# SS5: 100%|██████████| 11/11 [00:31<00:00,  2.89s/it]
# === Run 2/3 ===
# SS1: 100%|██████████| 24/24 [00:07<00:00,  3.26it/s]
# SS2: 100%|██████████| 24/24 [00:10<00:00,  2.33it/s]
# SS3: 100%|██████████| 24/24 [00:10<00:00,  2.34it/s]
# SS4: 100%|██████████| 18/18 [00:33<00:00,  1.84s/it]
# SS5: 100%|██████████| 11/11 [01:22<00:00,  7.55s/it]
# === Run 3/3 ===
# SS1: 100%|██████████| 24/24 [00:11<00:00,  2.01it/s]
# SS2: 100%|██████████| 24/24 [00:14<00:00,  1.71it/s]
# SS3: 100%|██████████| 24/24 [00:10<00:00,  2.30it/s]
# SS4: 100%|██████████| 18/18 [00:09<00:00,  1.93it/s]
# SS5: 100%|██████████| 11/11 [01:10<00:00,  6.37s/it]

# %%
plot("results/avg_easy_full_stopping_strategies_results_final.json", title = "Stopping Strategies on Istella22 using easy queries")
